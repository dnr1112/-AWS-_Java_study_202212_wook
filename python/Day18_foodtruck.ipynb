# %%
import numpy as np
import pandas as pd

food_df = pd.read_csv('전국푸드트럭허가구역표준데이터.csv', encoding = 'cp949')
food_df
# Out:
#                허가구역명  장소유형    시도명 시군구명  \
# 0         부산대학교내 장승터     6  부산광역시  금정구
# 1             금양초등학교     6  부산광역시  금정구
# 2    부산가톨릭대학교 로사리오광장     6  부산광역시  금정구
# 3          호계2차현대홈타운     8    경기도  안양시
# 4            안양종합운동장     8    경기도  안양시
# ..               ...   ...    ...  ...
# 337             정이네뜰     2    경기도  연천군
# 338          美, cafe    99    경기도  연천군
# 339             주영카페     2    경기도  연천군
# 340     동막골 유원지 협동조합     2    경기도  연천군
# 341     동막골 유원지 협동조합     2    경기도  연천군
#
#                                      소재지도로명주소               소재지지번주소  \
# 0                      부산광역시 금정구 부산대학로 63번길 2      부산광역시 금정구 장전동 40
# 1                         부산광역시 금정구 중앙대로 1755   부산광역시 금정구 부곡동 63-27
# 2    부산광역시 금정구 오륜대로 57, 부산가톨릭대학교 로사리오광장 (부곡동)       부산광역시 금정구 부곡동 9
# 3        경기도 안양시 동안구 경수대로 462 (호계동 호계2차현대홈타운)                   NaN
# 4                        경기도 안양시 동안구 평촌대로 389  경기도 안양시 동안구 비산동 1023
# ..                                        ...                   ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(pd.sum(4))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'sum'
