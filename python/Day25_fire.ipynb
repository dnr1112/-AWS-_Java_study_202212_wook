# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

font_path = "C:\Windows\Fonts\gulim.ttc"
kfont = matplotlib.font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rcParams['font.family'] = [kfont]

# %%
pd_data = pd.read_csv('시도별_화재발생_현황_총괄__20230307153254.csv', encoding = 'cp949')
pd_data_f = pd_data[pd_data['행정구역별'] != '전국']
pd_data_f
# Out:
#        시점    행정구역별  건수 (건) 사망 (명)  부상 (명)  재산피해(계) (천원)  부동산 (천원)   동산 (천원)  \
# 1    2010    서울특별시    5321     42     188      14503873   5948963   8554910
# 2    2010    부산광역시    2403     19      91      10546785   5580443   4966342
# 3    2010    대구광역시    1923     12      72       4637285   1996359   2640926
# 4    2010    인천광역시    1746     15      65      11614854   5362442   6252412
# 5    2010    광주광역시    1273      7      24       2729570   1358722   1370848
# ..    ...      ...     ...    ...     ...           ...       ...       ...
# 209  2021     전라북도    1984     10      80      19220779  10831162   8389617
# 210  2021     전라남도    2473     21      65      21988766   9622920  12365846
# 211  2021     경상북도    2849     21     188      38145736  15123537  23022199
# 212  2021     경상남도    2864     21     106      24941813  10954619  13987194
# 213  2021  제주특별자치도     544      3      19       6795271   2982411   3812860
#
#      이재가구수 (가구)  이재민수 (명)
# 1           131       277
# 2            46       126
# 3            62       137
# 4            68       167
# 5            27        71
# ..          ...       ...
# 209          55       125
# 210         156       298
# 211         129       234
# 212          65       127
# 213          13        21
#
# [202 rows x 10 columns]

# %%
fig1 = plt.figure()
a = fig1.add_subplot()
sns.lineplot(data = pd_data_f, x = '시점', y = '건수 (건)', hue = '행정구역별', ax = a)
# Out:
# <AxesSubplot: xlabel='시점', ylabel='건수 (건)'>
