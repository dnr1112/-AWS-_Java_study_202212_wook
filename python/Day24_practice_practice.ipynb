# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

pd_data = pd.read_csv('데이터산업_시장규모_20230306153111.csv', encoding = 'cp949')
pd_data
# Out:
#         시점  데이터 처리 및 관리 솔루션 개발·공급업  데이터 구축 및 컨설팅 서비스업  데이터 판매 및 제공 서비스업
# 0     2015                   14124              55280             64151
# 1     2016                   15720              55850             65977
# 2     2017                   16457              58894             68179
# 3     2018                   18617              61290             75778
# 4     2019                   20805              65412             82364
# 5     2020                   25133              76999             97891
# 6  2021 e)                   30566              86335            114071

# %%
x = pd_data['시점']
y1 = pd_data['데이터 처리 및 관리 솔루션 개발·공급업']
y2 = pd_data['데이터 구축 및 컨설팅 서비스업']
y3 = pd_data['데이터 판매 및 제공 서비스업']
fig, ax = plt.subplots()
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

# %%
pd_2015 = pd_data.iloc[0, :]

fig, ax = plt.subplots()
axes1 = ax.pie(pd_2015[1:])

pd_2021 = pd_data.iloc[6, :]

fig, ax = plt.subplots()
axes2 = ax.pie(pd_2021[1:])

# %%
# practice
fig = plt.figure()
fig.add_subplot(2, 1, 1)
fig.add_subplot(2, 2, 3)
fig.add_subplot(2, 2, 4)

axes0 = fig.axes[0]
fig, axes0 = plt.subplots()
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

axes1 = fig.axes[1]
axes1.pie(pd_2015[1:])

axes2 = fig.axes[2]
axes2.pie(pd_2012[1:])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 13
#      10 plt.plot(x, y2)
#      11 plt.plot(x, y3)
# ---> 13 axes1 = fig.axes[1]
#      14 axes1.pie(pd_2015[1:])
#      16 axes2 = fig.axes[2]
#
# IndexError: list index out of range
